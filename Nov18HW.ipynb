# %% [markdown]
# 1) name one purpose for github;
#
# to store multiple files in a publicly accessible repository for people to view
#
# 2) describe what is version control in your own words and how it could help you in your project;
#
# it allows for organization of a repositories at many different stages and versions of completeness
#
# 3) explain how in a group project (which we are not doing) github could help manage collaboration.
#
# You could use multiple branches, so that people could do their own work upload it and then compare with others in the group.
#
# 4) describe why employers might be interested in looking at a candidate's github sitr
#
# employers may want to see the work that acandidate has done and how they can manage many different files at different stages
